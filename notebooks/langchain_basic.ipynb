# %%
pip install python-dotenv langchain-openai langchain-community
# Out:
# Requirement already satisfied: python-dotenv in c:\users\somarya\anaconda3\lib\site-packages (1.1.0)
# Collecting langchain-openai
#   Downloading langchain_openai-0.3.28-py3-none-any.whl.metadata (2.3 kB)
# Collecting langchain-community
#   Downloading langchain_community-0.3.27-py3-none-any.whl.metadata (2.9 kB)
# Collecting langchain-core<1.0.0,>=0.3.68 (from langchain-openai)
#   Downloading langchain_core-0.3.69-py3-none-any.whl.metadata (5.8 kB)
# Collecting openai<2.0.0,>=1.86.0 (from langchain-openai)
#   Downloading openai-1.97.0-py3-none-any.whl.metadata (29 kB)
# Collecting tiktoken<1,>=0.7 (from langchain-openai)
#   Downloading tiktoken-0.9.0-cp313-cp313-win_amd64.whl.metadata (6.8 kB)
# Collecting langsmith>=0.3.45 (from langchain-core<1.0.0,>=0.3.68->langchain-openai)
#   Downloading langsmith-0.4.8-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\somarya\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.68->langchain-openai) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\somarya\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.68->langchain-openai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\somarya\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.68->langchain-openai) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\somarya\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.68->langchain-openai) (4.12.2)
# Requirement already satisfied: packaging>=23.2 in c:\users\somarya\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.68->langchain-openai) (24.2)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\somarya\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.68->langchain-openai) (2.10.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\somarya\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.68->langchain-openai) (2.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\somarya\anaconda3\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\somarya\anaconda3\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\somarya\anaconda3\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from openai<2.0.0,>=1.86.0->langchain-openai)
#   Downloading jiter-0.10.0-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: sniffio in c:\users\somarya\anaconda3\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\somarya\anaconda3\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (4.67.1)
# Requirement already satisfied: idna>=2.8 in c:\users\somarya\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.86.0->langchain-openai) (3.7)
# Requirement already satisfied: certifi in c:\users\somarya\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain-openai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\somarya\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\somarya\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain-openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\somarya\anaconda3\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.68->langchain-openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\somarya\anaconda3\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.68->langchain-openai) (2.27.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\somarya\anaconda3\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in c:\users\somarya\anaconda3\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.3)
# Collecting langchain<1.0.0,>=0.3.26 (from langchain-community)
#   Downloading langchain-0.3.26-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\somarya\anaconda3\lib\site-packages (from langchain-community) (2.0.39)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\somarya\anaconda3\lib\site-packages (from langchain-community) (3.11.10)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\somarya\anaconda3\lib\site-packages (from langchain-community) (2.6.1)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\somarya\anaconda3\lib\site-packages (from langchain-community) (2.1.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\somarya\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\somarya\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\somarya\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\somarya\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\somarya\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\somarya\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\somarya\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.8 (from langchain<1.0.0,>=0.3.26->langchain-community)
#   Using cached langchain_text_splitters-0.3.8-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\somarya\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\somarya\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\somarya\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\somarya\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain-openai)
#   Downloading orjson-3.11.0-cp313-cp313-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\somarya\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain-openai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\somarya\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain-openai) (0.23.0)
# Requirement already satisfied: colorama in c:\users\somarya\anaconda3\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.86.0->langchain-openai) (0.4.6)
# Downloading langchain_openai-0.3.28-py3-none-any.whl (70 kB)
# Downloading langchain_core-0.3.69-py3-none-any.whl (441 kB)
# Downloading openai-1.97.0-py3-none-any.whl (764 kB)
#    ---------------------------------------- 0.0/765.0 kB ? eta -:--:--
#    ---------------------------------------- 765.0/765.0 kB 3.9 MB/s eta 0:00:00
# Downloading jiter-0.10.0-cp313-cp313-win_amd64.whl (205 kB)
# Downloading tiktoken-0.9.0-cp313-cp313-win_amd64.whl (894 kB)
#    ---------------------------------------- 0.0/894.7 kB ? eta -:--:--
#    ---------------------------------------- 894.7/894.7 kB 3.6 MB/s eta 0:00:00
# Downloading langchain_community-0.3.27-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.5 MB 2.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.0/2.5 MB 3.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.8/2.5 MB 3.2 MB/s eta 0:00:01
#    ------------------------------------- -- 2.4/2.5 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 3.0 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Downloading langchain-0.3.26-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 4.0 MB/s eta 0:00:00
# Using cached langchain_text_splitters-0.3.8-py3-none-any.whl (32 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading langsmith-0.4.8-py3-none-any.whl (367 kB)
# Downloading orjson-3.11.0-cp313-cp313-win_amd64.whl (129 kB)
# Installing collected packages: typing-inspect, orjson, marshmallow, jiter, httpx-sse, tiktoken, dataclasses-json, openai, langsmith, langchain-core, langchain-text-splitters, langchain-openai, langchain, langchain-community
#
#    ----- ----------------------------------  2/14 [marshmallow]
#    ----------- ----------------------------  4/14 [httpx-sse]
#    ----------------- ----------------------  6/14 [dataclasses-json]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    -------------------- -------------------  7/14 [openai]
#    ---------------------- -----------------  8/14 [langsmith]
#    ---------------------- -----------------  8/14 [langsmith]
#    ---------------------- -----------------  8/14 [langsmith]
#    ---------------------- -----------------  8/14 [langsmith]
#    ---------------------- -----------------  8/14 [langsmith]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ---------------------------- ----------- 10/14 [langchain-text-splitters]
#    ------------------------------- -------- 11/14 [langchain-openai]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ---------------------------------- ----- 12/14 [langchain]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ---------------------------------------- 14/14 [langchain-community]
#
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.1 jiter-0.10.0 langchain-0.3.26 langchain-community-0.3.27 langchain-core-0.3.69 langchain-openai-0.3.28 langchain-text-splitters-0.3.8 langsmith-0.4.8 marshmallow-3.26.1 openai-1.97.0 orjson-3.11.0 tiktoken-0.9.0 typing-inspect-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv

load_dotenv()

openai_api_key = os.getenv("OPENAI_API_KEY")

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-3.5-turbo")

# %%
response = llm.invoke("Suggest me a title of movie to watch")

# %%
response
# Out:
# AIMessage(content='"The Infinite Now"', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 4, 'prompt_tokens': 16, 'total_tokens': 20, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-BvMMLUDx8OfRdICXVfQyvia99AKaB', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--e97bc1c8-c965-4bc9-b549-2928d076460b-0', usage_metadata={'input_tokens': 16, 'output_tokens': 4, 'total_tokens': 20, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
response.content
# Out:
# '"The Infinite Now"'
